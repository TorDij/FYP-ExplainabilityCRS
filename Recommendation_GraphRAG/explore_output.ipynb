# %%
import pandas as pd

# %%
df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/train_step0/artifacts/create_final_entities.parquet")
# mask = df['title'] == 'ARGO (2012)'
# df[mask]
df
# Out:
#                                        id  human_readable_id  \
# 0    95c85ba8-6bce-43b7-ad26-fa1419cc62eb                  0
# 1    ca9ebfa4-01c1-43ad-aaad-c4e88d17786c                  1
# 2    43e5e4ee-8c78-4013-8f3e-f75387316234                  2
# 3    8f993753-e1a7-4edf-9833-33c3fdf302e1                  3
# 4    fd279c31-b346-4722-8c2a-41bd36c747bf                  4
# ..                                    ...                ...
# 184  f27a632e-9df7-4a05-be9c-f6ac2427dbab                184
# 185  c5a6e1b2-b2e8-44b9-99a0-aeaa9d7e891f                185
# 186  399bdc20-143c-45f7-a7aa-27981da3eaab                186
# 187  59bbcaaa-5c2b-4ce2-8805-b3bed664c576                187
# 188  95cc3300-f744-4436-b764-991538bf46ec                188
#
#                          title              type  \
# 0               BEN-HUR (1959)             MOVIE
# 1    LAWRENCE OF ARABIA (1962)             MOVIE
# 2             GLADIATOR (2000)             MOVIE
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/train_step0/artifacts/create_final_relationships.parquet")
mask = (df['source'] == 'ARGO (2012)') | (df['target'] == 'ARGO (2012)')
df_filtered = df[mask]

df_filtered
# Out:
#                                      id  human_readable_id       source  \
# 0  ff8d31c5-42b0-4090-a424-48a334e4c0d3                  0  ARGO (2012)
#
#         target                   description  weight  combined_degree  \
# 0  BEN AFFLECK  Ben Affleck starred in Argo)     1.0                3
#
#                                        text_unit_ids
# 0  [4de866f2212ce103cd0a20857f269e552334429b8bd6c...

# %%
entities_df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/test_dialogue/artifacts/create_final_entities.parquet")
# Step 1: Filter first 5 "MOVIE" type entities
movies_filtered = entities_df[entities_df["type"] == "MOVIE"].head(8)

# Step 2: Keep all rows with types other than "MOVIE"
other_types = entities_df[entities_df["type"] != "MOVIE"]

# Step 3: Concatenate the results
filtered_df = pd.concat([movies_filtered, other_types])

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Prevent text truncation
filtered_df[['human_readable_id', 'title', 'type', 'description']]
# entities_df
# Out:
#     human_readable_id                             title      type  \
# 0                   0             SUPER TROOPERS (2001)     MOVIE
# 1                   1             POLICE ACADEMY (1984)     MOVIE
# 2                   2               AMERICAN PIE (1999)     MOVIE
# 3                   3              LETHAL WEAPON (1987)     MOVIE
# 4                   4          BEVERLY HILLS COP (1984)     MOVIE
# 5                   5                    48 HRS. (1982)     MOVIE
# 6                   6  A NIGHTMARE ON ELM STREET (1984)     MOVIE
# 7                   7            HAPPY DEATH DAY (2017)     MOVIE
# 28                 28                      EDDIE MURPHY     ACTOR
# 29                 29                     JASON BATEMAN     ACTOR
# 30                 30                  MELISSA MCCARTHY     ACTOR
# 31                 31                        EMMA STONE     ACTOR
# 32                 32                 QUENTIN TARANTINO  DIRECTOR
# ...

# %%
relationship_df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/test_dialogue/artifacts/create_final_relationships.parquet")
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Prevent text truncation
relationship_df[['human_readable_id', 'source',	'target', 'description']]
# Out:
#     human_readable_id                                                 source  \
# 0                   0                                  SUPER TROOPERS (2001)
# 1                   1                                  POLICE ACADEMY (1984)
# 2                   2                                   LETHAL WEAPON (1987)
# 3                   3                               BEVERLY HILLS COP (1984)
# 4                   4                       A NIGHTMARE ON ELM STREET (1984)
# 5                   5                      THE LAST HOUSE ON THE LEFT (1972)
# 6                   6                                  IDENTITY THIEF (2013)
# 7                   7                                  IDENTITY THIEF (2013)
# 8                   8                                  IDENTITY THIEF (2013)
# 9                   9                                        THE HEAT (2013)
# 10                 10                                          EASY A (2010)
# ...

# %%
# !pip install dataframe_image
# Out:
# ...
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 9.6 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 9.5 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
community_df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/test_dialogue/artifacts/create_final_community_reports.parquet")
community_df[['human_readable_id', 'title', 'summary', 'full_content', 'rank_explanation', 'findings', 'full_content_json']]
# Out:
#    human_readable_id                                                  title  \
# 0                  0  Avengers: Infinity War (2018) and Emma Stone's Impact
# 1                  1                             Spider-Man Movie Community
# 2                  2                 Marvel vs. X-Men: Clash of Superheroes
#
#                                                                                                                                                                                                                                                                                                                                                      summary  \
# ...

# %%
import matplotlib.pyplot as plt
import dataframe_image as dfi

# Load your dataframe (assuming it's already loaded)
row_index = 0  # Change this to the index of the record you want

# Extract a single row and format it
record = community_df.loc[row_index][['human_readable_id', 'title', 'summary', 'full_content', 
                         'rank_explanation', 'findings', 'full_content_json']].to_frame().T 

# Select columns and convert single row to a DataFrame
dfi.export(record, 'record.png')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[32], line 12
#       8 record = community_df.loc[row_index][['human_readable_id', 'title', 'summary', 'full_content',
#       9                          'rank_explanation', 'findings', 'full_content_json']].to_frame().T
#      11 # Select columns and convert single row to a DataFrame
# ---> 12 dfi.export(record, 'record.png')
#
# File ~/miniconda3/envs/graphrag/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:225, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi, use_mathjax, crop_top)
#     222 html = generate_html(obj, filename, max_rows, max_cols)
#     224 with disable_max_image_pixels():
# --> 225     img_str = converter(html)
#     227 save_image(img_str, filename)
#
# ...

# %%
df = pd.read_parquet("/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/train_step504/artifacts/create_final_entities.parquet")
df
# Out:
#                                        id  human_readable_id  \
# 0    7815e8e2-8cf5-4df4-920b-67d681385030                  0
# 1    b8d7f7d2-52f4-4766-a9e9-48dceca621b3                  1
# 2    5ae5af5a-5eed-4225-8030-d17b4f14ae41                  2
# 3    c718be12-2cd9-4259-b2cc-9fb0ca718967                  3
# 4    18d88d78-643a-49a1-aad8-435bf42d942e                  4
# ..                                    ...                ...
# 256  3f761b81-aca3-484a-84ba-0ef513df92e7                256
# 257  6203b744-9e3e-46f6-a9c9-70388e3f5b82                257
# 258  a22adc89-11f8-446f-a14e-d9f2bdfa92f2                258
# 259  f72b8425-1a8b-45a8-8fd8-c0180d15c47b                259
# 260  1bda422b-7d39-4f27-be82-a861def8844f                260
#
#                               title   type  \
# 0            JUST GO WITH IT (2011)  MOVIE
# 1    LOVE DON'T COST A THING (2003)  MOVIE
# 2                      MEAN GIRLS 2  MOVIE
# 3            MOMS' NIGHT OUT (2014)  MOVIE
# ...

# %%
df2 = pd.read_parquet("/home/Nema/UniCRS_GraphRAG/GraphRAG/output/successful_20250129-110435/artifacts/create_final_community_reports.parquet")
df2
# Out:
#                                     id  human_readable_id  community  parent  \
# 0     a6d11470f41f4ce0857ee2c9ec2f9a70               2200       2200    1618
# 1     aa3e76b5eb8a4cbaa7ed616a86ed9700               2201       2201    1618
# 2     bbdd83641cd24effa306de3ca7bf2c87               2202       2202    1618
# 3     deb2fc15b3134a3b81994c8b7034a630               2203       2203    1622
# 4     e1ad5a88df374a7fb0d4b37cc717189b               2204       2204    1622
# ...                                ...                ...        ...     ...
# 2223  976c20fa93d74066b5a57113979c26ea                 32         32      -1
# 2224  12db44a1af78422b9e80138c361e0508                 33         33      -1
# 2225  eaafd1da79f54374b0b1bc3a4aa40cd4                 34         34      -1
# 2226  f20aa1d5956648eea88399bd181d2b97                 35         35      -1
# 2227  f1fea4dc7c1641b5bc476f7283478056                 36         36      -1
#
# ...

# %%
df2.iloc[0]['findings']
# Out:
# array([{'explanation': 'Star Wars (1977) stands out as a cultural phenomenon that has captivated audiences worldwide. Its innovative storytelling, memorable characters, and groundbreaking visual effects have solidified its status as a timeless classic. [Data: Entities (627); Relationships (1697, 741, 27198, 29274)]', 'summary': 'Star Wars (1977) as a cultural phenomenon'},
#        {'explanation': "The Empire Strikes Back (1980) is a pivotal sequel in the Star Wars series, often regarded as superior to the original film. Its narrative depth, character development, and iconic moments have contributed significantly to the franchise's enduring legacy. [Data: Relationships (1697)]", 'summary': 'The impact of The Empire Strikes Back (1980)'},
# ...

# %%
df2.to_csv("/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/create_final_community_reports.csv")
